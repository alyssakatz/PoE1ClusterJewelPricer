# %%
import requests
import json
import pandas as pd

# %%
request = requests.get('https://poe.ninja/poe1/api/data/index-state').text
snapshots = json.loads(request)
snapshots = pd.json_normalize(snapshots['snapshotVersions']).apply(pd.Series)
snapshots

# %%
pd.options.display.float_format = '{:.2f}'.format

league = 'Mercenaries'
category = 'UniqueJewel'
items = ['Brute Force Solution', 'Energy From Within', 'Fertile Mind', 'Fevered Mind', 'Fortress Covenant', 'Healthy Mind', 'Powerlessness', 'Reckless Defence', 'Replica Powerlessness', 'To Dust']

# %%
uri = "https://poe.ninja/api/data/itemoverview?league=" + league + "&type=" + category

def get_item_overviews(league, category):
    df = pd.read_json(uri)
    df = df['lines'].apply(pd.Series)
    df = df[df['name'].isin(items)]
    df = df.reset_index(drop=True)
    return df

overviews = get_item_overviews(league, category)
overviews
# Out:
#        id                   name  \
# 0   22431      Fortress Covenant
# 1     489     Energy From Within
# 2     608           Healthy Mind
# 3  109200  Replica Powerlessness
# 4     525           Fertile Mind
# 5     526           Fevered Mind
# 6    1033       Reckless Defence
# 7    2184                To Dust
# 8     964          Powerlessness
# 9     211   Brute Force Solution
#
#                                                 icon      baseType  itemClass  \
# 0  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 1  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 2  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 3  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 4  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 5  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 6  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 7  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 8  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
# 9  https://web.poecdn.com/gen/image/WzI1LDE0LHsiZ...  Cobalt Jewel          3
#
#                                            sparkLine  \
# 0  {'totalChange': -54.76, 'data': [0, 4.75, 4.37...
# 1  {'totalChange': 5.26, 'data': [0, 2.63, 5.26, ...
# 2  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}
# 3  {'totalChange': 60, 'data': [0, 0, 0, 100, 100...
# 4  {'totalChange': 25, 'data': [0, 0, 0, 0, 25, 2...
# 5  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}
# 6  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}
# 7  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}
# 8  {'totalChange': 0, 'data': [0, 0, 7.5, 25, 0, ...
# 9  {'totalChange': 42.86, 'data': [0, 14.29, 19.0...
#
#                               lowConfidenceSparkLine implicitModifiers  \
# 0  {'totalChange': -54.76, 'data': [0, 4.75, 4.37...                []
# 1  {'totalChange': 5.26, 'data': [0, 2.63, 5.26, ...                []
# 2  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}                []
# 3  {'totalChange': 60, 'data': [0, 0, 0, 100, 100...                []
# 4  {'totalChange': 25, 'data': [0, 0, 0, 0, 25, 2...                []
# 5  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}                []
# 6  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}                []
# 7  {'totalChange': 0, 'data': [0, 0, 0, 0, 0, 0, 0]}                []
# 8  {'totalChange': 0, 'data': [0, 0, 7.5, 25, 0, ...                []
# 9  {'totalChange': 42.86, 'data': [0, 14.29, 19.0...                []
#
#   explicitModifiers                                        flavourText  \
# 0                []  Forsake what you might have had. Command power...
# 1                []  The Azmeri ascetics learnt the power\nof going...
# 2                []          For the ambitious, flesh is a limitation.
# 3                []  "The suppression troops have stopped respondin...
# 4                []  "The swallow flew fast and took many turns,\ns...
# 5                []              In sickness, the insane becomes sane.
# 6                []  There's no motivation for genius\nquite like d...
# 7                []  In the end, time comes for all of us.\nFor som...
# 8                []                   "Your desires will mislead you."
# 9                []  Picking a lock takes an immense amount of skil...
#
#    chaosValue  exaltedValue  divineValue  count  \
# 0       76.00          2.97         0.36     63
# 1       20.00          0.78         0.10     30
# 2       20.00          0.78         0.10    134
# 3       16.00          0.63         0.08     18
# 4        5.00          0.20         0.02    389
# 5        5.00          0.20         0.02    114
# 6        5.00          0.20         0.02    399
# 7        5.00          0.20         0.02    399
# 8        4.00          0.16         0.02    253
# 9        3.00          0.12         0.01    389
#
#                             detailsId tradeInfo  listingCount variant  \
# 0      fortress-covenant-cobalt-jewel        []          2957     NaN
# 1     energy-from-within-cobalt-jewel        []          1705     NaN
# 2           healthy-mind-cobalt-jewel        []          7252     NaN
# 3  replica-powerlessness-cobalt-jewel        []           430     NaN
# 4           fertile-mind-cobalt-jewel        []         19981     NaN
# 5           fevered-mind-cobalt-jewel        []          5308     NaN
# 6       reckless-defence-cobalt-jewel        []         28505     NaN
# 7                to-dust-cobalt-jewel        []         25280     NaN
# 8          powerlessness-cobalt-jewel        []         17420     NaN
# 9   brute-force-solution-cobalt-jewel        []         23209     NaN
#
#   itemType  levelRequired
# 0    Jewel            NaN
# 1    Jewel            NaN
# 2    Jewel            NaN
# 3    Jewel            NaN
# 4    Jewel            NaN
# 5    Jewel            NaN
# 6    Jewel            NaN
# 7    Jewel            NaN
# 8    Jewel            NaN
# 9    Jewel            NaN

# %%
item_uri_base = 'https://poe.ninja/poe1/api/economy/stash/current/item/history?league=' + league + '&type=' + category + '&id='

def calculate_weekly_stats(id):
    item_uri = item_uri_base + id
    tmp = pd.read_json(item_uri)
    tmp = tmp.reset_index(names='daysSinceStart')
    tmp = tmp.rename(columns={'value': 'chaos'})
    tmp = tmp.drop(columns=['daysAgo'])
    tmp['weekNum'] = tmp['daysSinceStart'] // 7

    stats = tmp.groupby('weekNum').agg(
        count_avg=('count', 'mean'),
        count_std=('count', 'std'),
        chaos_avg=('chaos', 'mean'),
        chaos_std=('chaos', 'std'))

    stats = stats.T
    flattened = pd.DataFrame()

    for col in stats:
        week_number = col
        week_prefix = f'week{week_number}'
        for index, value in stats[col].items():
            new_column_name = f'{week_prefix}_{index}'
            flattened[new_column_name] = [value]
    
    return flattened

def calculate_item_prices(df):
    item_prices = df['id'].astype(str).apply(calculate_weekly_stats)
    item_prices = pd.concat(list(item_prices), ignore_index=True)
    item_prices = df[['id', 'name', 'baseType', 'chaosValue']].join(item_prices)
    item_prices.rename(columns={'chaosValue': 'avg_chaos'})
    return item_prices

item_prices = calculate_item_prices(overviews)
item_prices
# Out:
#        id                   name      baseType  chaosValue  week0_count_avg  \
# 0   22431      Fortress Covenant  Cobalt Jewel       76.00           110.71
# 1     489     Energy From Within  Cobalt Jewel       20.00           117.14
# 2     608           Healthy Mind  Cobalt Jewel       20.00           220.71
# 3  109200  Replica Powerlessness  Cobalt Jewel       16.00            59.86
# 4     525           Fertile Mind  Cobalt Jewel        5.00           304.43
# 5     526           Fevered Mind  Cobalt Jewel        5.00           227.29
# 6    1033       Reckless Defence  Cobalt Jewel        5.00           302.43
# 7    2184                To Dust  Cobalt Jewel        5.00           303.86
# 8     964          Powerlessness  Cobalt Jewel        4.00           284.86
# 9     211   Brute Force Solution  Cobalt Jewel        3.00           308.14
#
#    week0_count_std  week0_chaos_avg  week0_chaos_std  week1_count_avg  \
# 0           104.29           157.30            32.59           396.14
# 1            75.59            10.30             1.69           392.29
# 2           169.13            74.58            56.15           398.86
# 3            31.41             1.57             0.53           137.43
# 4           165.95             1.60             0.85           399.00
# 5           167.48             1.86             1.46           399.00
# 6           167.96             1.58             0.78           399.00
# 7           166.51             1.57             0.79           399.00
# 8           175.74             1.00             0.00           399.00
# 9           161.25             1.26             0.44           399.00
#
#    week1_count_std  ...  week17_chaos_avg  week17_chaos_std  week18_count_avg  \
# 0             7.13  ...            135.80              2.20             62.71
# 1            17.76  ...             37.00              5.51             41.57
# 2             0.38  ...             14.44              4.05            153.00
# 3            11.44  ...             10.00              0.00             23.71
# 4             0.00  ...              4.54              0.44            352.71
# 5             0.00  ...              5.10              0.26            104.86
# 6             0.00  ...              5.00              0.00            399.00
# 7             0.00  ...              5.00              0.00            399.00
# 8             0.00  ...              4.58              0.46            215.57
# 9             0.00  ...              2.00              0.00            342.57
#
#    week18_count_std  week18_chaos_avg  week18_chaos_std  week19_count_avg  \
# 0              3.55            152.78             22.27             65.67
# 1              3.60             19.79              0.39             33.67
# 2              8.29             19.57              0.54            134.67
# 3              1.25             11.43              3.78             21.33
# 4              7.06              4.29              0.49            367.25
# 5              4.98              5.00              0.00            112.75
# 6              0.00              5.00              0.00            399.00
# 7              0.00              5.00              0.00            399.00
# 8             10.31              4.61              0.49            232.50
# 9             23.58              2.14              0.21            376.25
#
#    week19_count_std  week19_chaos_avg  week19_chaos_std
# 0              2.31            137.02             59.53
# 1              3.51             20.00              0.00
# 2              2.08             20.00              0.00
# 3              3.06             18.67              2.31
# 4             19.97              4.75              0.50
# 5              1.26              5.00              0.00
# 6              0.00              5.00              0.00
# 7              0.00              5.00              0.00
# 8             16.82              4.25              0.50
# 9             13.60              3.00              0.00
#
# [10 rows x 84 columns]

# %%
import re

wiki_uri = 'https://www.poewiki.net/wiki/'
corruption_chance_pattern = r"(?:or a )(\d*.\d+)(?:% chance per corrupted jewel)"

def get_corruption_chance(name):
    uri = wiki_uri + name
    html = requests.get(uri).text
    match = re.search(corruption_chance_pattern, html)

    if match:
        return match.group(1)
    else:
        return 'Unknown'

category = 'UniqueJewel'
items = ["Brute Force Solution", "Energy From Within", "Fertile Mind", "Fevered Mind", "Fortress Covenant", "Healthy Mind", "Powerlessness", "Reckless Defence", "Replica Powerlessness", "To Dust", "Atziri's Reign", "Efficient Training", "Energised Armour", "Fragility", "Inertia", "Rain of Splinters", "Careful Planning", "Chill of Corruption", "Fluid Motion", "Hidden Potential", "Pacifism", "Quickening Covenant", "Replica Pacifism", "Seething Fury", "Self-Flagellation", "The Golden Rule"]
corrupted_jewel_prices = calculate_item_prices(get_item_overviews(category, items))
url_names = corrupted_jewel_prices['name'].str.replace(' ', '_')
values = url_names.apply(get_corruption_chance)
corrupted_jewel_prices.insert(loc=3, column='corruptChance', value=values)
corrupted_jewel_prices
# Out:
#         id                   name        baseType corruptChance  chaosValue  \
# 0    22378    Quickening Covenant  Viridian Jewel       Unknown       79.60
# 1    22431      Fortress Covenant    Cobalt Jewel            .7       76.00
# 2     1007      Rain of Splinters   Crimson Jewel       Unknown       50.00
# 3      489     Energy From Within    Cobalt Jewel            .2       20.00
# 4      608           Healthy Mind    Cobalt Jewel            .9       20.00
# 5   109200  Replica Powerlessness    Cobalt Jewel       Unknown       16.00
# 6      266    Chill of Corruption  Viridian Jewel       Unknown       13.00
# 7    67169          Seething Fury  Viridian Jewel       Unknown       10.00
# 8   109024       Replica Pacifism  Viridian Jewel       Unknown        7.00
# 9      536           Fluid Motion  Viridian Jewel       Unknown        5.40
# 10     126         Atziri's Reign   Crimson Jewel       Unknown        5.00
# 11     226       Careful Planning  Viridian Jewel       Unknown        5.00
# 12     488       Energised Armour   Crimson Jewel       Unknown        5.00
# 13     525           Fertile Mind    Cobalt Jewel           6.8        5.00
# 14     526           Fevered Mind    Cobalt Jewel            .5        5.00
# 15     624       Hidden Potential  Viridian Jewel       Unknown        5.00
# 16     665                Inertia   Crimson Jewel       Unknown        5.00
# 17    1033       Reckless Defence    Cobalt Jewel           5.2        5.00
# 18    1109      Self-Flagellation  Viridian Jewel       Unknown        5.00
# 19    2184                To Dust    Cobalt Jewel           5.0        5.00
# 20    2276        The Golden Rule  Viridian Jewel       Unknown        5.00
# 21     964          Powerlessness    Cobalt Jewel           6.1        4.00
# 22     211   Brute Force Solution    Cobalt Jewel           4.3        3.00
# 23     477     Efficient Training   Crimson Jewel       Unknown        3.00
# 24     912               Pacifism  Viridian Jewel       Unknown        3.00
# 25     546              Fragility   Crimson Jewel       Unknown        1.80
#
#     week0_count_avg  week0_count_std  week0_chaos_avg  week0_chaos_std  \
# 0            132.43           147.89            18.57             7.79
# 1            110.71           104.29           157.30            32.59
# 2             54.71            58.25           231.47           137.51
# 3            117.14            75.59            10.30             1.69
# 4            220.71           169.13            74.58            56.15
# 5             59.86            31.41             1.57             0.53
# 6            252.14           162.01             1.00             0.00
# 7            267.43           178.61            60.19            71.28
# 8             50.14            23.02             2.02             0.06
# 9            266.86           179.27             5.21             3.98
# 10           260.43           181.86             1.57             0.78
# 11           289.57           186.97             5.86             3.13
# 12           252.86           190.68             8.64             4.19
# 13           304.43           165.95             1.60             0.85
# 14           227.29           167.48             1.86             1.46
# 15           207.14           171.53             1.46             0.77
# 16           339.00           149.27             3.29             2.98
# 17           302.43           167.96             1.58             0.78
# 18           327.57           148.61             2.14             1.35
# 19           303.86           166.51             1.57             0.79
# 20           290.71           159.06             2.35             0.79
# 21           284.86           175.74             1.00             0.00
# 22           308.14           161.25             1.26             0.44
# 23           318.14           152.97             1.01             0.04
# 24           285.86           174.26             1.14             0.38
# 25           298.43           173.38             1.14             0.38
#
#     week1_count_avg  ...  week17_chaos_avg  week17_chaos_std  \
# 0            399.00  ...             32.00              3.60
# 1            396.14  ...            135.80              2.20
# 2            362.71  ...             30.00              0.00
# 3            392.29  ...             37.00              5.51
# 4            398.86  ...             14.44              4.05
# 5            137.43  ...             10.00              0.00
# 6            399.00  ...              5.00              0.00
# 7            399.00  ...             10.00              0.00
# 8            118.29  ...              7.54              2.04
# 9            398.86  ...              5.00              0.00
# 10           399.00  ...              4.54              0.49
# 11           399.00  ...              5.00              0.00
# 12           399.00  ...              5.00              0.00
# 13           399.00  ...              4.54              0.44
# 14           399.00  ...              5.10              0.26
# 15           399.00  ...              5.00              0.00
# 16           399.00  ...              3.00              0.00
# 17           399.00  ...              5.00              0.00
# 18           399.00  ...              4.22              0.26
# 19           399.00  ...              5.00              0.00
# 20           399.00  ...              4.04              0.12
# 21           399.00  ...              4.58              0.46
# 22           399.00  ...              2.00              0.00
# 23           399.00  ...              2.01              0.04
# 24           399.00  ...              3.00              0.00
# 25           399.00  ...              1.00              0.00
#
#     week18_count_avg  week18_count_std  week18_chaos_avg  week18_chaos_std  \
# 0              47.00              3.06             54.11             17.94
# 1              62.71              3.55            152.78             22.27
# 2              53.29              2.29             29.71              0.39
# 3              41.57              3.60             19.79              0.39
# 4             153.00              8.29             19.57              0.54
# 5              23.71              1.25             11.43              3.78
# 6              60.14              2.79             10.07              6.89
# 7             105.00              2.77             10.00              0.00
# 8              16.14              2.73              5.64              0.85
# 9             292.00             20.21              5.04              0.11
# 10            126.29              6.24              4.46              0.51
# 11            358.29             14.08              5.00              0.00
# 12            181.29              3.77              5.00              0.00
# 13            352.71              7.06              4.29              0.49
# 14            104.86              4.98              5.00              0.00
# 15             96.71              6.21              5.00              0.00
# 16            399.00              0.00              3.00              0.00
# 17            399.00              0.00              5.00              0.00
# 18            238.86             11.60              4.17              0.30
# 19            399.00              0.00              5.00              0.00
# 20            290.00              9.40              4.02              0.09
# 21            215.57             10.31              4.61              0.49
# 22            342.57             23.58              2.14              0.21
# 23            399.00              0.00              2.30              0.43
# 24            233.29             13.29              3.00              0.00
# 25            282.43             10.34              1.00              0.00
#
#     week19_count_avg  week19_count_std  week19_chaos_avg  week19_chaos_std
# 0              47.00              2.83             79.90              4.08
# 1              65.67              2.31            137.02             59.53
# 2              53.00              3.83             35.50             11.73
# 3              33.67              3.51             20.00              0.00
# 4             134.67              2.08             20.00              0.00
# 5              21.33              3.06             18.67              2.31
# 6              54.00              2.65             17.27              3.72
# 7              98.00              2.65             10.00              0.00
# 8              13.33              1.15              6.33              1.15
# 9             276.50              8.74              6.95              2.29
# 10            122.25              3.77              5.00              0.00
# 11            339.50              6.56              5.00              0.00
# 12            175.00              4.83              5.00              0.00
# 13            367.25             19.97              4.75              0.50
# 14            112.75              1.26              5.00              0.00
# 15             89.00              3.56              5.00              0.00
# 16            399.00              0.00              3.50              1.00
# 17            399.00              0.00              5.00              0.00
# 18            223.25              6.99              4.83              0.35
# 19            399.00              0.00              5.00              0.00
# 20            284.25             14.01              4.75              0.50
# 21            232.50             16.82              4.25              0.50
# 22            376.25             13.60              3.00              0.00
# 23            399.00              0.00              3.00              0.00
# 24            224.50              8.19              3.02              0.05
# 25            295.50             18.41              1.70              0.48
#
# [26 rows x 85 columns]

# %%
corrupted_jewel_prices.to_excel("~/git/PoE1ClusterJewelPricer/CorruptedJewels.xlsx", sheet_name='Jewels', index=False)
